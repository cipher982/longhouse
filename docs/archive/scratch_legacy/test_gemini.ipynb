# %%
from google import genai

key = "AIzaSyCQ0KH_8gLhuzLIJ8keVwoudwSvvUHxbhk"
client = genai.Client(api_key=key)

# model = "gemini-2.5-flash-preview-04-17"
model = "gemini-2.5-pro-preview-03-25"

response = client.models.generate_content(
    model=model,
    contents="Explain how AI works in a few words",
)

print(response.text)
# Out:
# Okay, here are a few ways:
#
# *   **Computers learning from data to perform tasks.**
# *   **Machines finding patterns in data to make decisions.**
# *   **Software mimicking human intelligence using data.**
